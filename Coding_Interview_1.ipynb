# %% [markdown]
# 1. Given a limited range array contains both positive and non-positive numbers, i.e., elements are in the range from -MAX to +MAX. Our task is to search if some number is present in the array or not in O(1) time.

# %%
#1
MAX = 5
arr = range(-5,5)
dict1 = {}

for i in arr:
  dict1[i] = True

def fastSearch(dict1, i):
  try:
   if dict1[i]:
    print('present')

  except KeyError:
    print('not')
  return


fastSearch(dict1,10)
fastSearch(dict1,0)
# Out:
# not
# present

# %% [markdown]
# 2. create a 6 by 2 array with two for loops in one line

# %% [markdown]
# 3. Given a string A consisting of n characters and a string B consisting of m characters, write a function that will return the number of times A must be stated such that B is a substring of the repeated A. If B can never be a substring, return -1.

# %% [markdown]
# 4. You are given an array A containing 2*N+2 positive numbers, out of which 2*N numbers exist in pairs whereas the other two number occur exactly once and are distinct. You need to find the other two numbers and print them in ascending order.
#  Input :
# The first line contains a value T, which denotes the number of test cases. Then T test cases follow .The first line of each test case contains a value N. The next line contains 2*N+2 space separated integers.
# Output :
# Print in a new line the two numbers in ascending order.

# %%
input = [1, 2, 3, 2, 1, 4]

letters = []
notFound = 1

for i in range(0,len(input)):
  num = input.pop()
  if num not in input:
    letters.append(num)
    if len(letters) == 2:
      print(letters)
      break
# Out:
# [4, 3]

# %%
num = input.pop()
num
# Out:
# 1

# %% [markdown]
# 5. create an array from a raw input (ints separated by commas) in one line

# %% [markdown]
# 6. sort the 3 element in a 2d array

# %% [markdown]
# 7. Consider an undirected tree with N nodes, numbered from 1 to N. Each node has a label associated with it, which is an integer value. Different nodes can have the same label. Write a function that, given a zero indexed array A of length N, where A[j] is the label value of the (j + 1)-th node in the tree and a zero-indexed array E of length K = (N – 1) * 2 in which the edges of the tree are described, returns the length of the longest path such that all the nodes on that path have the same label. The length is the number of edges in that path.
# Example:
# A = [1, 1, 1, 2, 2]
# E = [1, 2, 1, 3, 2, 4, 2, 5]
# should return 2

# %% [markdown]
# 8. Question: Write a function that takes a list L and returns a random sublist of size N of that list. Assume that the indexes must be in increasing order. That is, you cannot go backwards.

# %% [markdown]
# 9. Implement a hash table in Python. In addition, show how to access the dictionary with it's key, how to update entries, how to add an entry, and how to delete an entry.

# %% [markdown]
# 10. Show how to create a list in python, for-loop through all the array values, add a value into the array, remove a value from the array, count the items of *a specific value* in the array, add another list to the array, return the index of an array value, and insert an element at a specific position.

# %% [markdown]
# 11. Show how to create an array of floats and access the first value of the array

# %% [markdown]
# 12. Impelement a stack in python, add a value to the stack, and then pop a value from the stack. Describe the difference between a stack, a queue, and a priority queue.

# %% [markdown]
# 13. what is a linked list? Implement a Node and LinkedList class with 3 nodes and traverse them printing the data from each node (by adding a function to the LinkedList class.) Connect 1->2->3.

# %% [markdown]
# 14. calculate the big O complexity of the items below:
#
# a. sorting a list
#
# b. appending to, fully clearing, calculating length of, setting an element to, popping from (eg. .pop()) a random item from **a set, list, or dict**.
#
# c. deleting or popping a list element, or comparing two list elements, or checking if something is in a list, or setting an item in a list equal to a value, or getting its max/min value
#
# d. comparing items in set s
#
# e. getting, popping, or setting an item in a dict
#
# f. O(N + Log N)
#
# g.
#   if test:
#      say block 1 is O(N**2)
#   else:
#      say block 2 is O(N)

# %%
# h
def is_unique1 (alist : [int]) -> bool:
    for i in range(len(alist)):		
        if alist[i] in alist[i+1:]:	
            return False		
    return True				

# this could also be written as:
def is_unique1 (alist : [int]) -> bool:
    for i in range(len(alist)):		
        for j in range(i+1,len(alist)): 
            if alist[i] == a[j]:	
                return False		
    return True

# %% [markdown]
# 15. Use a dict to find the intersection of 2 lists with less than O(N+M) time complexity if one list is length N and the other is length M.

# %% [markdown]
# 16. What are sets in Python good for? Implement a set and add an element to it and then discard it. Then create another sets of different length and compare the 2 sets. What is the time complexity of this?

# %%
# 17 
# find the complexity of the following alg
def is_unique2 (alist : [int]) -> bool:
    copy = list(alist)	
    copy.sort()			
    for i in range(len(alist)-1):	
        if copy[i] == copy[i+1]:
            return False
    return True

# %% [markdown]
# 18. Implement a priority queue in Python.

# %% [markdown]
# 19. Give an example of using the join function.

# %% [markdown]
# 20. Give an example of using the pow, trunc, round, ceil, and floor operations. Also, convert between float and int.

# %% [markdown]
# 21a. Sum the values in a dict that contains people and their incomes.

# %% [markdown]
# 21b. print the values of the dict in order.

# %% [markdown]
# 21c. pop the items from the dict until none are left. Raise a KeyError when none are left.

# %% [markdown]
# 21d. Use Pythons map function to apply a percentage decrease to each persons income.

# %% [markdown]
# 22. Given a length n, count the number of strings of length n that can be made using ‘a’, ‘b’ and ‘c’ with at-most one ‘b’ and two ‘c’s allowed.

# %% [markdown]
# 23. we are given an unordered list of numbers. check if any two add up to a sum in O(n).

# %% [markdown]
# 24. use one line of code to test for repeated values in a dictionary.

# %% [markdown]
# 25. create a tuple with 1 value and then add another tuple to it. Can we change items in a tuple?

# %% [markdown]
# 26. fastest way to hash a range(30) using dict.

# %% [markdown]
# 27. Given a string you need to print the size of the longest possible substring that has exactly k unique characters. If there is no possible substring print -1.

# %% [markdown]
# 28. Describe mergsort. in both bottom up and top down implementations. What are the worst and average-case runtimes?

# %% [markdown]
# 29. Describe quicksort. what is the worst and average-case runtimes?

# %% [markdown]
# 30. How many leaves are on a comparison sort binary tree? How many comparisons? What is the maximum number of leaves on a binary tree of height h?

# %% [markdown]
# 31a. what is insertion-sort?
# b. what is bubble-sort?
# c. what is heap-sort?
# d. what is Radix-sort?

# %% [markdown]
# 32a. What is NP?
# b. What is NP-hardness?
# c. What is NP-complete?

# %% [markdown]
# 33.
#
# a. What is the Traveling salesman problem? and what class is it in?
#
# b. The knapsack problem?
#
# c. Hamiltonian problem and Hamiltonian cycle problem?
#
# d. SAT?
#
# e. Subset-SUM?
#
# f. vertex cover?
#
# g. clique problem?

# %% [markdown]
# 34.
#
# a.What is a binary tree and what is a BST and what information do these store?
#
# b. what is the difference between BFS and DFS?

# %% [markdown]
# c. Implement the basic binary search tree construction and traversal (both directions). What is the time and space complexity of the traversals in each direction?

# %% [markdown]
# d. write a function to find the height of the tree.

# %% [markdown]
# e. Write a function to insert a node, to delete a node, and to search for a node. What is the time complexity of each?

# %% [markdown]
# 35. What is an N-ary tree? How do you find height?

# %% [markdown]
# 36. Write a function to determine whether the left and right subtree are balanced.

# %% [markdown]
# 37. What is a Red-Black Tree? (to much code and manipulations to add insert/delete info, so will bookmark pages.)

# %% [markdown]
# 38. What is a Domain Name System (DNS), and what is the DNS server?

# %% [markdown]
# 39. What is network load-balancing?

# %% [markdown]
# 40. What are threads?
